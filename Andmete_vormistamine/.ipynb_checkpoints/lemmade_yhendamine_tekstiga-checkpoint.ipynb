# %%
import sqlite3
import pandas as pd
andmebaasi_nimi = "v33_koondkorpus_sentences_verb_pattern_obl_20241002-130310.db"
tabel = "kohakaanded" # tabel, kus on ainult kohakäänded alles jäetud (feats_filtreerimine.ipynb tulemus)

# %%
examples_given = 5 # mitu rida iga lemma kohta välja valitakse
count_min = 50 # minimaalne lemma esinemiste kord, et seda välja valitaks
conn = sqlite3.connect(andmebaasi_nimi)
query = f"""
WITH RankedRows AS (
    -- Järjestame samad lemmad kasutades random'it ning määrame example_num väärtuse
    SELECT 
        *, 
        ROW_NUMBER() OVER (PARTITION BY lemma ORDER BY RANDOM()) AS example_num,
        COUNT(*) OVER (PARTITION BY lemma) AS total_count -- Mitu korda antud lemma esineb
    FROM {tabel}
),
ValidLemmas AS (
    -- Jätame alles ainult lemmad, mis esinevad vähemalt count_min korda
    SELECT lemma
    FROM RankedRows
    GROUP BY lemma
    HAVING COUNT(*) >= {count_min}
),
RandomLemmas AS (
    -- Valime juhuslikult lemmad
    SELECT lemma
    FROM ValidLemmas
    ORDER BY RANDOM()
    -- LIMIT 1000 (siin saab määrata mitu erinevat lemmat valitakse)
)
SELECT RankedRows.*
FROM RankedRows
JOIN RandomLemmas USING (lemma)
WHERE example_num <= {examples_given}
ORDER BY total_count, lemma, example_num;
"""


df = pd.read_sql_query(query, conn)
conn.close()
df # dataframe, kus on iga valitud lemma kohta examples_given näidet
# Out:
#              id   head_id  loc  loc_rel deprel       form lemma  \
# 0       6673242   3564213    1       -1    obl   30ndatel   30.
# 1      42341265  22893450    1       -1    obl   30-ndail   30.
# 2      21006672  11264349    1       -1    obl   30ndatel   30.
# 3      40112877  21678755    5        3    obl  30-ndatel   30.
# 4      19900674  10650110    7        2    obl  30-ndatel   30.
# ...         ...       ...  ...      ...    ...        ...   ...
# 45440   2973758   1617003    5        2    obl      meile  mina
# 45441  37104196  20082178    8       -1    obl      mulle  mina
# 45442  21188779  11364599    3        1    obl        mul  mina
# 45443  36355130  19684261    6        1    obl      meile  mina
# 45444  53676070  29836651    6       -2    obl      mulle  mina
#
#                  feats parent_loc pos case number proper  example_num  \
# 0          ad,l,ord,pl       None   N   ad     pl      0            1
# 1      ad,ord,pl,roman       None   N   ad     pl      0            2
# 2      ad,ord,pl,roman       None   N   ad     pl      0            3
# 3      ad,ord,pl,roman       None   N   ad     pl      0            4
# 4          ad,l,ord,pl       None   N   ad     pl      0            5
# ...                ...        ...  ..  ...    ...    ...          ...
# 45440           all,pl       None   P  all     pl      0            1
# 45441           all,sg       None   P  all     sg      0            2
# 45442            ad,sg       None   P   ad     sg      0            3
# 45443           all,pl       None   P  all     pl      0            4
# 45444           all,sg       None   P  all     sg      0            5
#
#        total_count
# 0               50
# 1               50
# 2               50
# 3               50
# 4               50
# ...            ...
# 45440       209164
# 45441       209164
# 45442       209164
# 45443       209164
# 45444       209164
#
# [45445 rows x 15 columns]

# %%
conn = sqlite3.connect(andmebaasi_nimi)

db_df = pd.read_sql("SELECT id, sentence_id FROM transaction_head", conn) # saame sentance_id

conn.close()

# lisame sentence_id oma dataframe'ile
df = df.merge(db_df, left_on="head_id", right_on="id", how="left")

# eemaldame üleliigse id veeru
df.drop(columns=["id_y"], inplace=True)

df.head(50)
# Out:
#         id_x   head_id  loc  loc_rel deprel                form  \
# 0    6673242   3564213    1       -1    obl            30ndatel
# 1   42341265  22893450    1       -1    obl            30-ndail
# 2   21006672  11264349    1       -1    obl            30ndatel
# 3   40112877  21678755    5        3    obl           30-ndatel
# 4   19900674  10650110    7        2    obl           30-ndatel
# 5   10675961   5708794    4        1    obl        Himaalajasse
# 6   24690736  13309281   16       -2    obl         Himaalajalt
# 7    4248645   2286553    1       -1    obl          Himaalajas
# 8   23773137  12801746    3       -1    obl         Himaalajale
# 9   42439763  22947391    1       -2    obl          Himaalajas
# 10  23239625  12508029    4       -2    obl      Holmenkollenis
# 11  24199739  13035691    4        2    obl      Holmenkollenis
# 12  46486722  25310854    7        2    obl      Holmenkollenis
# 13   3838710   2070557    1       -1    obl      Holmenkollenis
# 14  23354409  12572782    4        2    obl      Holmenkollenis
# 15  40489234  21882624    3        1    obl            Kelamilt
# 16  33418151  18122593   18        1    obl            Kelamile
# 17  14109560   7559863    3        1    obl          Kelamitele
# 18  14753907   7901948    5        1    obl            Kelamilt
# 19  14914176   7986761   12        2    obl            Kelamist
# 20  45077287  24458331    5        2    obl           Keskturul
# 21  45042939  24438379    1       -1    obl           Keskturul
# 22  48131297  26282450    8       -1    obl           Keskturul
# 23  45064691  24450951   10       -1    obl           Keskturul
# 24  41175964  22256386    2       -1    obl           Keskturul
# 25  45343970  24620275    3        1    obl          Kristusest
# 26  50624241  27834985    6        2    obl          Kristusest
# 27  50650183  27850695   25        1    obl         Kristusesse
# 28  43946573  23811292    4        1    obl          Kristusele
# 29  26562489  14342529    5        3    obl          Kristusele
# 30  44532242  24149451   37       -2    obl  Lõuna-Prantsusmaal
# 31   1005146    588666   15        1    obl  Lõuna-Prantsusmaal
# 32  41295107  22320194    5        2    obl  Lõuna-Prantsusmaal
# 33  47998727  26207447    6        2    obl  Lõuna-Prantsusmaal
# 34  17983898   9614242   14        1    obl  Lõuna-Prantsusmaal
# 35  36200740  19600263    1       -1    obl            Marikale
# 36  35079248  19001668    6       -2    obl            Marikale
# 37  15292511   8184250   15        3    obl            Marikale
# 38  16879026   9023387    9       -1    obl            Marikale
# 39  21255255  11399490    5        1    obl            Marikale
# 40  39004006  21087140    8        1    obl        Newcastle'il
# 41  11883648   6363114    4        3    obl       Newcastle'ile
# 42  12611937   6754200    5        2    obl      Newcastle'isse
# 43  47220516  25744341    7        3    obl       Newcastle'ile
# 44   6094645   3256197    9        1    obl       Newcastle'ile
# 45  31330699  16971669    5        3    obl         Novgorodist
# 46  16605152   8877857   10        3    obl          Novgorodis
# 47  38654676  20902260   28        2    obl          Novgorodis
# 48  40923542  22117501    8        6    obl          Novgorodis
# 49  13617460   7298156    3        1    obl         Novgorodile
#
#                 lemma            feats parent_loc pos case number proper  \
# 0                 30.      ad,l,ord,pl       None   N   ad     pl      0
# 1                 30.  ad,ord,pl,roman       None   N   ad     pl      0
# 2                 30.  ad,ord,pl,roman       None   N   ad     pl      0
# 3                 30.  ad,ord,pl,roman       None   N   ad     pl      0
# 4                 30.      ad,l,ord,pl       None   N   ad     pl      0
# 5           Himaalaja      ill,prop,sg       None   S  ill     sg      1
# 6           Himaalaja      abl,prop,sg       None   S  abl     sg      1
# 7           Himaalaja       in,prop,sg       None   S   in     sg      1
# 8           Himaalaja      all,prop,sg       None   S  all     sg      1
# 9           Himaalaja       in,prop,sg       None   S   in     sg      1
# 10      Holmenkolleni       in,prop,sg       None   S   in     sg      1
# 11      Holmenkolleni       in,prop,sg       None   S   in     sg      1
# 12      Holmenkolleni       in,prop,sg       None   S   in     sg      1
# 13      Holmenkolleni       in,prop,sg       None   S   in     sg      1
# 14      Holmenkolleni       in,prop,sg       None   S   in     sg      1
# 15              Kelam      abl,prop,sg       None   S  abl     sg      1
# 16              Kelam      all,prop,sg       None   S  all     sg      1
# 17              Kelam      all,pl,prop       None   S  all     pl      1
# 18              Kelam      abl,prop,sg       None   S  abl     sg      1
# 19              Kelam       el,prop,sg       None   S   el     sg      1
# 20           Keskturg       ad,prop,sg       None   S   ad     sg      1
# 21           Keskturg       ad,prop,sg       None   S   ad     sg      1
# 22           Keskturg       ad,prop,sg       None   S   ad     sg      1
# 23           Keskturg       ad,prop,sg       None   S   ad     sg      1
# 24           Keskturg       ad,prop,sg       None   S   ad     sg      1
# 25            Kristus       el,prop,sg       None   S   el     sg      1
# 26            Kristus       el,prop,sg       None   S   el     sg      1
# 27            Kristus      ill,prop,sg       None   S  ill     sg      1
# 28            Kristus      all,prop,sg       None   S  all     sg      1
# 29            Kristus      all,prop,sg       None   S  all     sg      1
# 30  Lõuna-Prantsusmaa       ad,prop,sg       None   S   ad     sg      1
# 31  Lõuna-Prantsusmaa       ad,prop,sg       None   S   ad     sg      1
# 32  Lõuna-Prantsusmaa       ad,prop,sg       None   S   ad     sg      1
# 33  Lõuna-Prantsusmaa       ad,prop,sg       None   S   ad     sg      1
# 34  Lõuna-Prantsusmaa       ad,prop,sg       None   S   ad     sg      1
# 35             Marika      all,prop,sg       None   S  all     sg      1
# 36             Marika      all,prop,sg       None   S  all     sg      1
# 37             Marika      all,prop,sg       None   S  all     sg      1
# 38             Marika      all,prop,sg       None   S  all     sg      1
# 39             Marika      all,prop,sg       None   S  all     sg      1
# 40          Newcastle       ad,prop,sg       None   S   ad     sg      1
# 41          Newcastle      all,prop,sg       None   S  all     sg      1
# 42          Newcastle      ill,prop,sg       None   S  ill     sg      1
# 43          Newcastle      all,prop,sg       None   S  all     sg      1
# 44          Newcastle      all,prop,sg       None   S  all     sg      1
# 45           Novgorod       el,prop,sg       None   S   el     sg      1
# 46           Novgorod       in,prop,sg       None   S   in     sg      1
# 47           Novgorod       in,prop,sg       None   S   in     sg      1
# 48           Novgorod       in,prop,sg       None   S   in     sg      1
# 49           Novgorod      all,prop,sg       None   S  all     sg      1
#
#     example_num  total_count  sentence_id
# 0             1           50      2228206
# 1             2           50     14476563
# 2             3           50      7012123
# 3             4           50     13556739
# 4             5           50      6618141
# 5             1           50      3545266
# 6             2           50      8302648
# 7             3           50      1437124
# 8             4           50      7982872
# 9             5           50     14510969
# 10            1           50      7802178
# 11            2           50      8122635
# 12            3           50     16369327
# 13            4           50      1303240
# 14            5           50      7846423
# 15            1           50     13695417
# 16            2           50     11308585
# 17            3           50      4704988
# 18            4           50      4921524
# 19            5           50      4973962
# 20            1           50     15674510
# 21            2           50     15661606
# 22            3           50     17099474
# 23            4           50     15669861
# 24            5           50     13980901
# 25            1           50     15805498
# 26            2           50     18362308
# 27            3           50     18371359
# 28            4           50     15245924
# 29            5           50      8922478
# 30            1           50     15463647
# 31            2           50       379037
# 32            3           50     14020166
# 33            4           50     17050602
# 34            5           50      5990594
# 35            1           50     12243134
# 36            2           50     11874806
# 37            3           50      5099303
# 38            4           50      5627172
# 39            5           50      7089542
# 40            1           50     13180611
# 41            2           50      3950988
# 42            3           50      4196921
# 43            4           50     16732116
# 44            5           50      2039463
# 45            1           50     10587899
# 46            2           50      5536560
# 47            3           50     13062920
# 48            4           50     13870486
# 49            5           50      4540427

# %%
# kasutame lausete andmebaasi
conn = sqlite3.connect("v33_koondkorpus_sentences_sentences_20250220-130121.db")

db_df = pd.read_sql("SELECT id, text FROM sentences", conn) # saame laused (text)
conn.close()
# lisame sentence_id põhjal dataframe'i ridadele vastava lause
df = df.merge(db_df, left_on="sentence_id", right_on="id", how="left")
# eemaldame üleliigse id veeru
df.drop(columns=["id"], inplace=True)
# muudame veerude järjekorda
uus_järjekord = ["lemma", "sentence_id", "head_id", "example_num","total_count","feats","case", "number", "proper","deprel","form", "loc", "loc_rel", "parent_loc", "pos","id_x", "text"]
df = df[uus_järjekord]
df
# Out:
#       lemma  sentence_id   head_id  example_num  total_count            feats  \
# 0       30.      2228206   3564213            1           50      ad,l,ord,pl
# 1       30.     14476563  22893450            2           50  ad,ord,pl,roman
# 2       30.      7012123  11264349            3           50  ad,ord,pl,roman
# 3       30.     13556739  21678755            4           50  ad,ord,pl,roman
# 4       30.      6618141  10650110            5           50      ad,l,ord,pl
# ...     ...          ...       ...          ...          ...              ...
# 45440  mina      1015405   1617003            1       209164           all,pl
# 45441  mina     12547861  20082178            2       209164           all,sg
# 45442  mina      7070579  11364599            3       209164            ad,sg
# 45443  mina     12296318  19684261            4       209164           all,pl
# 45444  mina     20940121  29836651            5       209164           all,sg
#
#       case number proper deprel       form  loc  loc_rel parent_loc pos  \
# 0       ad     pl      0    obl   30ndatel    1       -1       None   N
# 1       ad     pl      0    obl   30-ndail    1       -1       None   N
# 2       ad     pl      0    obl   30ndatel    1       -1       None   N
# 3       ad     pl      0    obl  30-ndatel    5        3       None   N
# 4       ad     pl      0    obl  30-ndatel    7        2       None   N
# ...    ...    ...    ...    ...        ...  ...      ...        ...  ..
# 45440  all     pl      0    obl      meile    5        2       None   P
# 45441  all     sg      0    obl      mulle    8       -1       None   P
# 45442   ad     sg      0    obl        mul    3        1       None   P
# 45443  all     pl      0    obl      meile    6        1       None   P
# 45444  all     sg      0    obl      mulle    6       -2       None   P
#
#            id_x                                               text
# 0       6673242  30ndatel tuli juba helifilm peale ja paljud va...
# 1      42341265       30-ndail kuivas see tuluallikas väiksemaks .
# 2      21006672  30ndatel kasutas valitsus analoogilise protest...
# 3      40112877              Filmitäht tuli temast aga 30-ndatel .
# 4      19900674  " See meenutab väga vapside liikumist 30-ndate...
# ...         ...                                                ...
# 45440   2973758          Paraku ei jätku supermehi meile kõigile .
# 45441  37104196  ” Oh , mis nüüd lastest – mulle meeldib nende ...
# 45442  21188779  Fath soovitas mul kutsuda välja ainult surnuid...
# 45443  36355130  Nii et ajalugu on andnud meile näite “ ajaloo ...
# 45444  53676070      plika_tartust|afk: njaa mulle kahm meeldib :P
#
# [45445 rows x 17 columns]

# %%
# salvestame saadud dataframe'i andmebaasi
conn = sqlite3.connect("BT_andmed.db") 

df.to_sql("table", conn, if_exists="replace", index=False)
conn.close()

# %% [markdown]
# # Lisa - vali saadud andmetest esimesed 5000 rida

# %%
# valime välja esimesed 5000
'''
conn = sqlite3.connect("BT_andmed.db")

db_df = pd.read_sql('SELECT * FROM "table" LIMIT 5000;', conn)
conn.close()
db_df
'''
# Out:
#          lemma  sentence_id   head_id  example_num  total_count  \
# 0          30.      2228206   3564213            1           50
# 1          30.     14476563  22893450            2           50
# 2          30.      7012123  11264349            3           50
# 3          30.     13556739  21678755            4           50
# 4          30.      6618141  10650110            5           50
# ...        ...          ...       ...          ...          ...
# 4995  patriarh      3177549   5102847            1           58
# 4996  patriarh      7821476  12534525            2           58
# 4997  patriarh      7871695  12611437            3           58
# 4998  patriarh      6441025  10355610            4           58
# 4999  patriarh     10765198  17243938            5           58
#
#                 feats case number proper deprel         form  loc  loc_rel  \
# 0         ad,l,ord,pl   ad     pl      0    obl     30ndatel    1       -1
# 1     ad,ord,pl,roman   ad     pl      0    obl     30-ndail    1       -1
# 2     ad,ord,pl,roman   ad     pl      0    obl     30ndatel    1       -1
# 3     ad,ord,pl,roman   ad     pl      0    obl    30-ndatel    5        3
# 4         ad,l,ord,pl   ad     pl      0    obl    30-ndatel    7        2
# ...               ...  ...    ...    ...    ...          ...  ...      ...
# 4995       all,com,sg  all     sg      0    obl  patriarhile   25        1
# 4996       all,com,sg  all     sg      0    obl  patriarhile   24       -1
# 4997       abl,com,sg  abl     sg      0    obl  patriarhilt   17        2
# 4998       all,com,sg  all     sg      0    obl  patriarhile   16        4
# 4999       all,com,sg  all     sg      0    obl  patriarhile    7        1
#
#      parent_loc pos      id_x  \
# 0          None   N   6673242
# 1          None   N  42341265
# 2          None   N  21006672
# 3          None   N  40112877
# 4          None   N  19900674
# ...         ...  ..       ...
# 4995       None   S   9563434
# 4996       None   S  23287070
# 4997       None   S  23422233
# 4998       None   S  19356671
# 4999       None   S  31823066
#
#                                                    text
# 0     30ndatel tuli juba helifilm peale ja paljud va...
# 1          30-ndail kuivas see tuluallikas väiksemaks .
# 2     30ndatel kasutas valitsus analoogilise protest...
# 3                 Filmitäht tuli temast aga 30-ndatel .
# 4     " See meenutab väga vapside liikumist 30-ndate...
# ...                                                 ...
# 4995  TALLINN , 17. veebruar ( EPLO ) - Kunstnik Aap...
# 4996  Eesti Apostliku Õigeusu Kirikule tagastatakse ...
# 4997  16. sajandi lõpul nõudsid Vene valitsejad Ivan...
# 4998  Eelmises riigikogus õigeusuliste saadikurühma ...
# 4999  Nemad alluvad Moskva ja kogu Venemaa patriarhi...
#
# [5000 rows x 17 columns]

# %%
# salvestame saadud read andmebaasi faili
'''
conn = sqlite3.connect("BT_andmed_5000.db") 

df.to_sql("table", conn, if_exists="replace", index=False)
conn.close()
'''
